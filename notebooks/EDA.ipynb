# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wine=pd.read_csv(r"D:\RESUME ML PROJECTS\WINE_QUALITY\notebooks\wine_quality\winequality-red.csv")

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
wine.shape
# Out:
# (1599, 12)

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine.duplicated().sum()
# Out:
# 240

# %%
wine=wine.drop_duplicates()

# %%
wine.shape
# Out:
# (1359, 12)

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1359 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1359 non-null   float64
#  1   volatile acidity      1359 non-null   float64
#  2   citric acid           1359 non-null   float64
#  3   residual sugar        1359 non-null   float64
#  4   chlorides             1359 non-null   float64
#  5   free sulfur dioxide   1359 non-null   float64
#  6   total sulfur dioxide  1359 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1359 non-null   float64
#  9   sulphates             1359 non-null   float64
#  10  alcohol               1359 non-null   float64
#  11  quality               1359 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 138.0 KB

# %% [markdown]
# visualization

# %%
wine.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5

# %%
sns.catplot(x="quality",data= wine,kind= 'count',color="g")

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'volatile acidity', data = wine)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %% [markdown]
# volatile acidity is higher in low quality wine and
#
#  volatile acidity is low in high qulaity wine

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'fixed acidity', data = wine)
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %% [markdown]
# almost fixed acidity is equal chance in qulaity of the wine

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'citric acid', data = wine)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %% [markdown]
# Citric acid is low in low quality of the wine and
#
# high in high quality of the wine
#
# it is directly proportional

# %%
wine.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'residual sugar', data = wine)
# Out:
# <Axes: xlabel='quality', ylabel='residual sugar'>

# %% [markdown]
# Residula sugar is also equal in all categories quality of the wine

# %%
sns.histplot(wine["pH"])
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %% [markdown]
# pH value rangong between 2.8 to 4.0 and middle of the ph value is almost 3.3

# %%
sns.histplot(wine["alcohol"])
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     0.996709
# std       0.049377            10.447270             33.408946     0.001869
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996700
# 75%       0.091000            21.000000             63.000000     0.997820
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1359.000000  1359.000000  1359.000000  1359.000000
# mean      3.309787     0.658705    10.432315     5.623252
# std       0.155036     0.170667     1.082065     0.823578
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
plt.figure(figsize=(10,9))
sns.heatmap(wine.corr(),cbar=True, square=True, fmt = '.2f', annot = True, annot_kws={'size':8}, cmap = 'Blues')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,7))
sns.boxplot(wine)
# Out:
# <Axes: >

# %%
columns_to_check = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
                    'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
                    'pH', 'sulphates', 'alcohol']
# Function to remove outliers based on IQR for multiple columns
def remove_outliers_iqr(wine, columns):
    for column in columns:
        Q1 = wine[column].quantile(0.25)
        Q3 = wine[column].quantile(0.75)
        IQR = Q3 - Q1
        
        # Filter out rows with outliers
        wine = wine[(wine[column] >= Q1 - 1.5 * IQR) & (wine[column] <= Q3 + 1.5 * IQR)]
    return wine

# Apply the function to remove outliers from the specified columns
wine = remove_outliers_iqr(wine, columns_to_check)
print("Data without outliers:")
print(wine)
# Out:
# Data without outliers:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1590            6.3             0.550         0.15             1.8      0.077
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1597            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1597                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 5         9.4        5
# ...       ...      ...
# 1590     11.6        6
# 1592     11.0        6
# 1593      9.5        6
# 1594     10.5        5
# 1597     10.2        5
#
# [881 rows x 12 columns]

# %%
wine.shape
# Out:
# (881, 12)

# %%
plt.figure(figsize=(20,7))
sns.boxplot(wine)
# Out:
# <Axes: >

# %%
x=wine.drop(columns="quality")
y=wine["quality"]

# %%
print(x)
print(y)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1590            6.3             0.550         0.15             1.8      0.077
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1597            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1597                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 5         9.4
# ...       ...
# 1590     11.6
# 1592     11.0
# 1593      9.5
# 1594     10.5
# 1597     10.2
#
# [881 rows x 11 columns]
# 0       5
# 1       5
# 2       5
# 3       6
# 5       5
#        ..
# 1590    6
# 1592    6
# 1593    6
# 1594    5
# 1597    5
# Name: quality, Length: 881, dtype: int64

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 5       5
#        ..
# 1590    6
# 1592    6
# 1593    6
# 1594    5
# 1597    5
# Name: quality, Length: 881, dtype: int64

# %%
Y = wine['quality'].apply(lambda y_value: 1 if y_value>=7 else 0)

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 5       0
#        ..
# 1590    0
# 1592    0
# 1593    0
# 1594    0
# 1597    0
# Name: quality, Length: 881, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,Y,test_size=0.2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (881, 11) (704, 11) (177, 11)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier

# %%
models={
    "Logistic":LogisticRegression(),
    "decision":DecisionTreeClassifier(),
    "random":RandomForestClassifier(),
    "gradient":GradientBoostingClassifier(),
    "adaboost":AdaBoostClassifier()}

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

model_list = []
accuracy_scores = []

# Iterate over models
for i in range(len(list(models))):
    model_name = list(models.keys())[i]
    model = list(models.values())[i]
    model.fit(x_train_scaled, y_train)
    
    # Predictions
    y_train_pred = model.predict(x_train_scaled)
    y_test_pred = model.predict(x_test_scaled)
    
    # Evaluation function for classification
    def evaluate_model(true, predicted):
        accuracy = accuracy_score(true, predicted)
        precision = precision_score(true, predicted, average='weighted', zero_division=1)
        recall = recall_score(true, predicted, average='weighted', zero_division=1)
        f1 = f1_score(true, predicted, average='weighted', zero_division=1)
        return accuracy, precision, recall, f1
    
    # Evaluate model performance on training and test data
    model_train_accuracy, model_train_precision, model_train_recall, model_train_f1 = evaluate_model(y_train, y_train_pred)
    model_test_accuracy, model_test_precision, model_test_recall, model_test_f1 = evaluate_model(y_test, y_test_pred)
    
    # Print the model name
    print(f"Model: {model_name}")
    model_list.append(model_name)
    
    # Print training performance
    print("Performance for Train Data")
    print(f"Accuracy: {model_train_accuracy:.4f}")
    print(f"Precision: {model_train_precision:.4f}")
    print(f"Recall: {model_train_recall:.4f}")
    print(f"F1 Score: {model_train_f1:.4f}")
    
    print("--------------------------------------------------")
    
    # Print test performance
    print("Performance for Test Data")
    print(f"Accuracy: {model_test_accuracy:.4f}")
    print(f"Precision: {model_test_precision:.4f}")
    print(f"Recall: {model_test_recall:.4f}")
    print(f"F1 Score: {model_test_f1:.4f}")
    accuracy_scores.append(model_test_accuracy)
    
    print("=" * 35)
    print('\n')

# Optional: After the loop, you can display a summary of the performance for all models
print("Model Comparison")
for model, score in zip(model_list, accuracy_scores):
    print(f"{model}: Test Accuracy = {score:.4f}")
# Out:
# Model: Logistic
# Performance for Train Data
# Accuracy: 0.9048
# Precision: 0.8928
# Recall: 0.9048
# F1 Score: 0.8944
# --------------------------------------------------
# Performance for Test Data
# Accuracy: 0.8814
# Precision: 0.8616
# Recall: 0.8814
# F1 Score: 0.8692
# ===================================
#
#
# Model: decision
# Performance for Train Data
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# --------------------------------------------------
# Performance for Test Data
# Accuracy: 0.8588
# Precision: 0.8620
# Recall: 0.8588
# F1 Score: 0.8603
# ===================================
#
#
# Model: random
# Performance for Train Data
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# --------------------------------------------------
# Performance for Test Data
# Accuracy: 0.8870
# Precision: 0.8546
# Recall: 0.8870
# F1 Score: 0.8630
# ===================================
#
#
# Model: gradient
# Performance for Train Data
# Accuracy: 0.9759
# Precision: 0.9758
# Recall: 0.9759
# F1 Score: 0.9750
# --------------------------------------------------
# Performance for Test Data
# Accuracy: 0.8927
# Precision: 0.8671
# Recall: 0.8927
# F1 Score: 0.8726
# ===================================
#
#
# Model: adaboost
# Performance for Train Data
# Accuracy: 0.9531
# Precision: 0.9513
# Recall: 0.9531
# F1 Score: 0.9517
# --------------------------------------------------
# Performance for Test Data
# Accuracy: 0.8757
# Precision: 0.8510
# Recall: 0.8757
# F1 Score: 0.8607
# ===================================
#
#
# Model Comparison
# Logistic: Test Accuracy = 0.8814
# decision: Test Accuracy = 0.8588
# random: Test Accuracy = 0.8870
# gradient: Test Accuracy = 0.8927
# adaboost: Test Accuracy = 0.8757
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.datasets import load_iris

# Sample data (replace with your own dataset)
data = load_iris()
X, y = data.data, data.target

# Define models and their hyperparameters
models = {
    "Logistic": LogisticRegression(),
    "DecisionTree": DecisionTreeClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "GradientBoosting": GradientBoostingClassifier()
}

params = {
    "Logistic": {
        'penalty': ['l1', 'l2', 'elasticnet'],
        'solver': ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']
    },
    "DecisionTree": {
        'criterion': ['gini', 'entropy'],
        'max_depth': [None, 5, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    },
    "AdaBoost": {
        'n_estimators': [50, 100, 150, 200],
        'learning_rate': [0.01, 0.1, 0.5, 1.0],
        'algorithm': ['SAMME', 'SAMME.R']
    },
    "GradientBoosting": {
        'n_estimators': [50, 100, 150],
        'learning_rate': [0.01, 0.1, 0.5],
        'max_depth': [3, 5, 10]
    }
}

# Loop through models and perform RandomizedSearchCV
for model_name, model in models.items():
    print(f"Training {model_name} model...")

    # Perform RandomizedSearchCV
    random_search = RandomizedSearchCV(estimator=model, param_distributions=params[model_name], n_iter=10, cv=5, random_state=42)
    random_search.fit(x_train_scaled, y_train)

    # Best parameters and score
    print(f"Best parameters for {model_name}: {random_search.best_params_}")
    print(f"Best score for {model_name}: {random_search.best_score_}")
    print("-" * 50)
# Out:
# Training Logistic model...
# Best parameters for Logistic: {'solver': 'newton-cg', 'penalty': 'l2'}
# Best score for Logistic: 0.8948834853090173
# --------------------------------------------------
# Training DecisionTree model...
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 30 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cholesky supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\linear_model\_logistic.py", line 75, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or None penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cholesky supports only 'l2' or None penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1194, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan 0.89345491 0.89488349 0.89203647        nan        nan
#         nan        nan 0.89488349        nan]
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Best parameters for DecisionTree: {'min_samples_split': 10, 'min_samples_leaf': 4, 'max_depth': 10, 'criterion': 'gini'}
# Best score for DecisionTree: 0.8849442755825734
# --------------------------------------------------
# Training AdaBoost model...
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\HP\anaconda3\anacondasharmi\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Best parameters for AdaBoost: {'n_estimators': 200, 'learning_rate': 1.0, 'algorithm': 'SAMME'}
# Best score for AdaBoost: 0.9019959473150962
# --------------------------------------------------
# Training GradientBoosting model...
# Best parameters for GradientBoosting: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.1}
# Best score for GradientBoosting: 0.8991185410334346
# --------------------------------------------------

# %%
y_train_random=random_search.predict(x_train_scaled)
y_test_random=random_search.predict(x_test_scaled)

score_train_random=accuracy_score(y_train,y_train_random)
score_test_random=accuracy_score(y_test,y_test_random)

print("training score after hyperparameter tuning is",score_train_random)
print("testing score after hyperparameter tuning is",score_test_random)
# Out:
# training score after hyperparameter tuning is 0.9659090909090909
# testing score after hyperparameter tuning is 0.8813559322033898
